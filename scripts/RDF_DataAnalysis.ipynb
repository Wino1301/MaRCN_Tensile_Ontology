# %%
import os
import pandas as pd
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, XSD

# Define namespaces
CORE = Namespace("https://w3id.org/pmd/co/")
TTO = Namespace("https://w3id.org/pmd/tto/")
RDF_SYNTAX = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
XSD_NS = Namespace("http://www.w3.org/2001/XMLSchema#")

# Define the base directory
base_dir = "D:/FAIR_Ontology/MaRCN_Tensile_Ontology/results"

# List to store the data
data = []

# Traverse the directory structure
for material_folder in os.listdir(base_dir):
    material_path = os.path.join(base_dir, material_folder)
    if os.path.isdir(material_path):
        for test_folder in os.listdir(material_path):
            test_path = os.path.join(material_path, test_folder)
            if os.path.isdir(test_path):
                for ttl_file in os.listdir(test_path):
                    if ttl_file.endswith('.ttl'):
                        ttl_path = os.path.join(test_path, ttl_file)
                        # Load the RDF graph
                        g = Graph()
                        g.parse(ttl_path, format='ttl')
                        
                        # Extract data from the graph
                        for s, p, o in g.triples((None, RDF.type, TTO.TensileTest)):
                            material_designation = g.value(s, CORE.MaterialDesignation)
                            primary_data = g.value(s, CORE.PrimaryData)
                            secondary_data = g.value(s, CORE.SecondaryData)
                            original_gauge_length = g.value(s, TTO.OriginalGaugeLength)
                            original_thickness = g.value(s, TTO.OriginalThickness)
                            original_width = g.value(s, TTO.OriginalWidth)
                            percentage_extension = g.value(s, TTO.PercentageExtension)
                            ultimate_tensile_strength = g.value(s, TTO.UltimateTensileStrength)
                            yield_strength = g.value(s, TTO.YieldStrength)
                            youngs_modulus = g.value(s, TTO.YoungsModulus)

                            # Create a dictionary with the data
                            data.append({
                                "MaterialDesignation": str(material_designation),
                                "PrimaryData": str(primary_data),
                                "SecondaryData": str(secondary_data),
                                "OriginalGaugeLength": float(g.value(original_gauge_length, RDF.value)),
                                "OriginalThickness": float(g.value(original_thickness, RDF.value)),
                                "OriginalWidth": float(g.value(original_width, RDF.value)),
                                "PercentageExtension": float(g.value(percentage_extension, RDF.value)),
                                "UltimateTensileStrength": float(g.value(ultimate_tensile_strength, RDF.value)),
                                "YieldStrength": float(g.value(yield_strength, RDF.value)),
                                "YoungsModulus": float(g.value(youngs_modulus, RDF.value))
                            })

# Create a dataframe from the data
df = pd.DataFrame(data)

# %%
df
# Out:
#    MaterialDesignation                                        PrimaryData  \
# 0       Aluminium_6061  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 1       Aluminium_6061  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 2       Aluminium_6061  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 3       Aluminium_6061  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 4       Aluminium_6061  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 5                Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 6                Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 7                Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 8                Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 9                Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 10               Brass  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 11          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 12          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 13          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 14          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 15          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 16          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 17          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 18          Steel_1018  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 19          Steel_4130  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 20          Steel_4130  https://github.com/Wino1301/MaRCN_Tensile_Onto...
# 21          Steel_4130  https://github.com/Wino1301/MaRCN_Tensile_Onto...
#
#                                         SecondaryData  OriginalGaugeLength  \
# 0   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 1   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 2   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 3   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 4   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 5   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 6   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 7   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 8   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 9   https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 10  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 11  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 12  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 13  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 14  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 15  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 16  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 17  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 18  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 19  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 20  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
# 21  https://github.com/Wino1301/MaRCN_Tensile_Onto...                 50.0
#
#     OriginalThickness  OriginalWidth  PercentageExtension  \
# 0               3.090         13.490               0.1827
# 1               3.150         13.590               0.1298
# 2               3.120         13.530               0.1851
# 3               3.194         13.630               0.1727
# 4               3.140         12.640               0.1725
# 5               3.080         13.250               0.2280
# 6               3.210         13.520               0.2753
# 7               3.230         13.430               0.2768
# 8               3.190         13.500               0.3018
# 9               3.190         13.500               0.2763
# 10              3.143         13.506               0.2839
# 11              3.610         13.470               0.2850
# 12              3.180         13.450               0.2901
# 13              3.140         13.520               0.2743
# 14              3.170         13.493               0.2904
# 15              3.140         13.480               0.2837
# 16              3.150         13.500               0.2851
# 17              3.180         13.460               0.3004
# 18              3.140         13.490               0.2782
# 19              3.150         13.400               0.2846
# 20              3.190         13.480               0.2823
# 21              3.250         13.523               0.2837
#
#     UltimateTensileStrength  YieldStrength  YoungsModulus
# 0                     293.5        187.809        58884.0
# 1                     234.4        160.378        56336.0
# 2                     356.1        242.538        66047.0
# 3                     227.7        142.127        49341.0
# 4                     301.5        199.250        58626.0
# 5                     508.1        351.396       114939.0
# 6                     508.3        340.055        93366.0
# 7                     535.5        357.794        84768.0
# 8                     439.8        281.533        78659.0
# 9                     434.5        279.564        67453.0
# 10                  62815.5      41186.180     11217442.0
# 11                    361.2        287.240       155690.0
# 12                    521.3        268.537       139306.0
# 13                    324.9        258.560       119696.0
# 14                    375.2        288.827       134593.0
# 15                    377.9        294.611       146999.0
# 16                    336.7        261.067       150489.0
# 17                    272.7        198.946        87986.0
# 18                    410.1        324.400       133112.0
# 19                    526.4        298.802       124814.0
# 20                    506.0        281.078       140602.0
# 21                    458.8        251.291       123105.0

# %%
import os
import pandas as pd
from rdflib import Graph, Namespace, RDF, Literal
from rdflib.namespace import XSD
import requests

# Define namespaces
CORE = Namespace("https://w3id.org/pmd/co/")
TTO = Namespace("https://w3id.org/pmd/tto/")
RDF_SYNTAX = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
XSD_NS = Namespace("http://www.w3.org/2001/XMLSchema#")

# Base URL for the GitHub repository
base_url = "https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/"

# List to store the data
data = []

# Materials and tests to process
materials = ["Steel_1018", "Steel_4130", "Brass"]
tests = ["Tensile_001", "Tensile_002", "Tensile_003", "Tensile_004", "Tensile_005", "Tensile_006"]

# Function to download and parse TTL files
def download_and_parse_ttl(url):
    response = requests.get(url)
    response.raise_for_status()
    g = Graph()
    g.parse(data=response.text, format='ttl')
    return g

# Process each material and test
for material in materials:
    for test in tests:
        ttl_url = f"{base_url}{material}/{test}/{test}.ttl"
        try:
            # Download and parse the TTL file
            g = download_and_parse_ttl(ttl_url)
            
            # Extract data from the graph
            for s, p, o in g.triples((None, RDF.type, TTO.TensileTest)):
                material_designation = g.value(s, CORE.MaterialDesignation)
                primary_data = g.value(s, CORE.PrimaryData)
                secondary_data = g.value(s, CORE.SecondaryData)
                original_gauge_length = g.value(s, TTO.OriginalGaugeLength)
                original_thickness = g.value(s, TTO.OriginalThickness)
                original_width = g.value(s, TTO.OriginalWidth)
                percentage_extension = g.value(s, TTO.PercentageExtension)
                ultimate_tensile_strength = g.value(s, TTO.UltimateTensileStrength)
                yield_strength = g.value(s, TTO.YieldStrength)
                youngs_modulus = g.value(s, TTO.YoungsModulus)

                # Create a dictionary with the data
                data.append({
                    "MaterialDesignation": str(material_designation),
                    "PrimaryData": str(primary_data),
                    "SecondaryData": str(secondary_data),
                    "OriginalGaugeLength": float(g.value(original_gauge_length, RDF.value)),
                    "OriginalThickness": float(g.value(original_thickness, RDF.value)),
                    "OriginalWidth": float(g.value(original_width, RDF.value)),
                    "PercentageExtension": float(g.value(percentage_extension, RDF.value)),
                    "UltimateTensileStrength": float(g.value(ultimate_tensile_strength, RDF.value)),
                    "YieldStrength": float(g.value(yield_strength, RDF.value)),
                    "YoungsModulus": float(g.value(youngs_modulus, RDF.value))
                })

        except requests.exceptions.RequestException as e:
            print(f"Failed to download {ttl_url}: {e}")

# Create a dataframe from the data
df = pd.DataFrame(data)
# Out:
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_001/Tensile_001.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_001/Tensile_001.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_002/Tensile_002.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_002/Tensile_002.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_003/Tensile_003.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_003/Tensile_003.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_004/Tensile_004.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_004/Tensile_004.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_005/Tensile_005.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_005/Tensile_005.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_006/Tensile_006.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_1018/Tensile_006/Tensile_006.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_001/Tensile_001.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_001/Tensile_001.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_002/Tensile_002.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_002/Tensile_002.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_003/Tensile_003.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_003/Tensile_003.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_004/Tensile_004.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_004/Tensile_004.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_005/Tensile_005.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_005/Tensile_005.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_006/Tensile_006.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Steel_4130/Tensile_006/Tensile_006.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_001/Tensile_001.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_001/Tensile_001.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_002/Tensile_002.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_002/Tensile_002.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_003/Tensile_003.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_003/Tensile_003.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_004/Tensile_004.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_004/Tensile_004.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_005/Tensile_005.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_005/Tensile_005.ttl
# Failed to download https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_006/Tensile_006.ttl: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Wino1301/MaRCN_Tensile_Ontology/main/data/ReportRaw/Brass/Tensile_006/Tensile_006.ttl
