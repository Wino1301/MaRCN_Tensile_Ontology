# %% [markdown]
# # FAIR Application using Tensile Testing Ontology
#
# Authors: [Erwin Cazares<sup>1</sup>](ecazares3@miners.utep.edu), [Dr Brian E. Schuster<sup>1</sup>](bschuster@utep.edu) </br>
#
# <sup>1</sup> Dynamic Materials Laboratory at University of Texas at El Paso, TX USA 79968</br>
#
# Date of creation: Summer 2024 </br>
# Date of last revision: Summer 2024 </br>

# %% [markdown]
# # Tensile Data Results for FAIR
#
# This code analyzes a single experiment of tensile data for Aluminium 6061, and saves all data collected under PMDco ontology for later use.
#
# Note: Refer to Tensile.py for the bacth processing of all the test in the "data" folder.
#
# It will output 5 images and a text file that contains analyzis results for Sample geometry, Young's Modulus,
# .2% YS, Modulus of Resilience, Strain Energy Density @ 0.2%, Toughness,
# UTS, Final Strain(ef), and elastic recovery(er)

# %% [markdown]
# ## Define working directories and results path

# %%
import subprocess
import os

# Get the directory of the current script or the parent directory
script_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in locals() else os.path.dirname(os.getcwd())
print(f'Current working directory = {script_dir}')

def install_requirements(requirements_file):
    try:
        subprocess.check_call(['pip', 'install', '-r', requirements_file])
        print("Successfully installed dependencies from", requirements_file)
    except subprocess.CalledProcessError as e:
        print("Error installing dependencies:", e)

if __name__ == "__main__":
    requirements_file = os.path.join(script_dir, "requirements.txt")
    install_requirements(requirements_file)
# Out:
# Current working directory = D:\FAIR_Ontology
# Successfully installed dependencies from D:\FAIR_Ontology\requirements.txt

# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from rdflib import Graph, URIRef, Literal, Namespace, RDF
import re

# Relative path to the data folder
data_folder = os.path.join(script_dir, 'data')
print(f'Path to data folder = {data_folder}')

# Create and Append a Text File with Data
def txtEdit(text, func):
    with open(os.path.join(img_path, material + '.txt'), func) as file:
        file.write(text)

def stress_from_load(l,w,t,mm_in=False):
    if mm_in == True:
        wi = w/25.4
        ti = t/25.4
        area = wi*ti
    else:
        area = w*t
    strs = l/area
    return(strs)

def strain_from_displacement(d,lngth):
    strn = d/lngth
    return(strn)

def true_from_eng(a,b):
    sigma_t = np.copy(a)
    epsilon_t = np.copy(b)
    ii=0
    for ii in range(len(a)):
        sigma_t[ii] = a[ii]*(1+b[ii])
        epsilon_t[ii] = np.log(1+b[ii])
    return(sigma_t,epsilon_t)
# Out:
# Path to data folder = D:\FAIR_Ontology\data

# %% [markdown]
# ## Load Tensile Data from Excel Reports
#
# - Extracts all file names from data folder and creates result folder for individual test
# - Creates text file for analyzis
# - Loads Load-Displacement data from excel file

# %%
# Access data files using relative paths
data_folder = r'D:\FAIR_Ontology\data\PrimaryData\1018_Steel'  # Use raw string to handle backslashes

tensile_basename_list = sorted(
    [os.path.basename(x) for x in glob.glob(os.path.join(data_folder, '*.xlsx'))]
)

print(tensile_basename_list)

# Create Results Folder
try: 
    os.mkdir(os.path.join(script_dir, 'results'))
except(FileExistsError, IndexError, ValueError, ZeroDivisionError) as e:
    print(e)   
    
img_folder_path = os.path.join(script_dir, 'results')
print(f'Results folder path = {img_folder_path}')

for filename in tensile_basename_list[:-1]:
    print(filename)
    
fname = os.path.join(data_folder, filename)
material = filename.replace('.xlsx','')
print(material)
    
try: 
    os.mkdir(os.path.join(img_folder_path, material))
except(FileExistsError, IndexError, ValueError, ZeroDivisionError) as e:
    print(e)
    
img_path = os.path.join(img_folder_path, material)
print(f'Metadata Result File = {img_path}')
txtEdit(os.path.join(img_path, material)+'\n\n','w')

try:
    df = pd.read_excel(fname, sheet_name='Sheet2', header=None)
    print("Successfully read the Excel file.")
except Exception as e:
    print("Error occurred while reading the Excel file:", e)
    print('Data Name Convention Breached\n\n')
    txtEdit('Data Name Convention Breached\n\n','a')
    
    #continue
# Out:
# ['1018 Steel.xlsx', '1018 Steel2.xlsx', '1018 Steel3.xlsx', '1018 Steel5.xlsx', '1018 Steel6.xlsx', '1018 Steel7.xlsx', '1018 Steel8.xlsx', '1018 Steel9.xlsx']
# [WinError 183] Cannot create a file when that file already exists: 'D:\\FAIR_Ontology\\results'
# Results folder path = D:\FAIR_Ontology\results
# 1018 Steel.xlsx
# 1018 Steel2.xlsx
# 1018 Steel3.xlsx
# 1018 Steel5.xlsx
# 1018 Steel6.xlsx
# 1018 Steel7.xlsx
# 1018 Steel8.xlsx
# 1018 Steel8
# [WinError 183] Cannot create a file when that file already exists: 'D:\\FAIR_Ontology\\results\\1018 Steel8'
# Metadata Result File = D:\FAIR_Ontology\results\1018 Steel8
# Successfully read the Excel file.

# %% [markdown]
# ## Explore Sample Geometry
#
# Explores the report sheet of the excel to extract the following
# - Lenght
# - Width
# - Thickness
# - Units
#
# It appends this info to the material's result txt file

# %%
#Find Column Index of mm
dfcol = df
col = dfcol
for i in range(len(col)):
    try:
        if any(dfcol.iloc[i].str.contains('mm')==True):
            breakpoint = i
            break
    #Uniformalize? the Data
    except(AttributeError):
        dfcol = dfcol.T
        dfcol.insert(0,'0',np.nan)
        dfcol = dfcol.T
        dfcol.fillna('empty',inplace=True)
        if any(dfcol.iloc[i].str.contains('mm')==True):
            breakpoint = i
            break
            
# print(dfcol.iloc[breakpoint])

# Save raw data to a DataFrame
raw_data_df = dfcol.copy() 

# Drop rows before the header row
raw_data_df = raw_data_df.iloc[breakpoint:]

# Drop the first row as it contains the headers
raw_data_df = raw_data_df.iloc[1:]

# Save processed stress-strain data to CSV files
raw_data_df.to_csv(os.path.join(img_path,'raw_load_disp_data.csv'), index=False)

print("Raw Data Stored to raw_data_df")
print(f"Raw Data Saved to = {os.path.join(img_path,'raw_load_disp_data.csv')}")


try:
    df2 = pd.read_excel(fname, sheet_name='Test Report')
except:
    print('Data Name Convention Breached\n\n')
    txtEdit('Data Name Convention Breached\n\n','a')
    #continue
    
#Find Length
a = np.where(df2['Default Test Run Report'].str.contains('Initial Marked Gage Length')==True)
a = int(a[0])
dflen = pd.read_excel(fname, sheet_name='Test Report',skiprows=a,nrows=1)
dflen = dflen.T
s_length = dflen.iloc[1,0]
print('Length:'+str(s_length))
txtEdit('Length:'+str(s_length)+'\n','a')
    
#Find Width
a = np.array(np.where(df2['Default Test Run Report'].str.contains('Width')==True)).flatten()
a = int(a[0])
dfw = pd.read_excel(fname, sheet_name='Test Report',skiprows=a,nrows=1)
dfw = dfw.T
width = dfw.iloc[1,0]
print('Width:'+str(width))
txtEdit('Width:'+str(width)+'\n','a')
    
#Find Thickness
a = np.array(np.where(df2['Default Test Run Report'].str.contains('Thickness')==True)).flatten()
a = int(a[0])
dft = pd.read_excel(fname, sheet_name='Test Report',skiprows=a,nrows=1)
dft = dft.T
thickness = dft.iloc[1,0]
print('Thickness:'+str(thickness))
txtEdit('Thickness:'+str(thickness)+'\n','a')
    
#Find Stress and Strain
try:
    dfdat = pd.read_excel(fname, sheet_name='Sheet2',skiprows=breakpoint)
    dfdat.dropna(subset=['mm'],inplace=True)
    completion = True
except:
    completion = False
 
    if completion == False:
        try:
            dfdat = pd.read_excel(fname, sheet_name='Sheet2',skiprows=breakpoint+1)
            dfdat.dropna(subset=['mm'],inplace=True)
        except:
            print('Data Layout Unsupported\n\n')
            txtEdit('Data Layout Unsupported\n\n','a')
            #continue
        
try:
    dfdat.dropna(subset=['N'],inplace=True)
    load = np.array(dfdat['N'])
    stress = stress_from_load(load,width,thickness)
    y_units = 'MPa'
    print('Units: MPa')
    txtEdit('Units: MPa'+'\n','a')
except:
    dfdat.dropna(subset=['lbf'],inplace=True)
    load = np.array(dfdat['lbf'])
    stress = stress_from_load(load,width,thickness,mm_in=True)
    y_units = 'psi'
    print('Units: psi')
    txtEdit('Units: psi'+'\n','a')
    
displacement = np.array(dfdat['mm'])
strain = strain_from_displacement(displacement,s_length)
# Out:
# Raw Data Stored to raw_data_df
# Raw Data Saved to = D:\FAIR_Ontology\results\1018 Steel8\raw_load_disp_data.csv
# Length:50
# Width:13.46
# Thickness:3.18
# Units: MPa

# %% [markdown]
# ## Generate Stress-Strain Graph
#
# - Cleans load-displacement data and converts it to stress-strain
# - Plots and saves the result

# %%
"""
Smooth Dataset
"""

#Set Moving Window
winSize = 25
    
smooth_x = np.array([])
smooth_y = np.array([])
length = len(stress)
j=0
while j < length - 1:
    #print("j:", j, "length:", length)  # Debugging print statement
    check = np.sign(stress[j])
    try:
        strain[j+1]
    except:
        if check < 0:
            stress = np.delete(stress, j)
            strain = np.delete(strain, j)
            break
        
    if check < 0:
        stress = np.delete(stress, j)
        strain = np.delete(strain, j)
        j = j - 1
    elif np.sign(strain[j+1] - strain[j]) < 0:
        stress = np.delete(stress, j)
        strain = np.delete(strain, j)
        j = j - 1
    else:
        pass
    length = len(stress)
    j = j + 1
 #   print(stress)
    
i = 0
while i < len(strain):
    datx = np.average(strain[i:i+winSize])
    daty = np.average(stress[i:i+winSize])
    datarrX = np.array([datx])
    datarrY = np.array([daty])
    smooth_x = np.append(smooth_x,datarrX)
    smooth_y = np.append(smooth_y,datarrY)
    i = i+winSize
    
# Create DataFrames for processed stress-strain data
processed_stress_strain_df = pd.DataFrame({'strain': smooth_x, 'stress': smooth_y})

# Save processed stress-strain data to CSV files
processed_stress_strain_df.to_csv(os.path.join(img_path,'engineering_stress_strain_data.csv'), index=False)

print("Processed Engineering Data Stored to processed_stress_strain_df")
print(f"Processed Engineering Saved to = {os.path.join(img_path,'engineering_stress_strain_data.csv')}")

#print(smooth_x,smooth_y)
fig,ax = plt.subplots(figsize=(10,10))
figname = str(material) + ' Stress-Strain Graph'
plt.title(figname)
plt.ylabel('Stress ('+y_units+')')
plt.xlabel("Strain")
plt.plot(smooth_x,smooth_y,marker='o',color='black')
fig.savefig(os.path.join(img_path, figname) + '.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Processed Engineering Data Stored to processed_stress_strain_df
# Processed Engineering Saved to = D:\FAIR_Ontology\results\1018 Steel8\engineering_stress_strain_data.csv

# %% [markdown]
# ## Plot True Stress-Strain Graph
#
# - Calculates true stress and strain from and plots it alongside with the engineering stress-strain
# - Saves the plot

# %%
"""
True Stress/Strain
"""
#Call function
true_smooth_y,true_smooth_x = true_from_eng(smooth_y,smooth_x)

# Create DataFrames for processed stress-strain data
true_stress_strain_df = pd.DataFrame({'strain': true_smooth_x, 'stress': true_smooth_y})

# Save processed stress-strain data to CSV files
true_stress_strain_df.to_csv(os.path.join(img_path,'ture_stress_strain_data.csv'), index=False)

print("Processed True Data Stored to true_stress_strain_df")
print(f"Processed True Saved to = {os.path.join(img_path,'ture_stress_strain_data.csv')}")

    
#Plot True Stress/Strain
fig,ax = plt.subplots(figsize=(10,10))
figname = str(material)+' True Stress-Strain Graph'
plt.title(figname)
plt.ylabel('Stress ('+y_units+')')
plt.xlabel("Strain")
plt.plot(smooth_x,smooth_y,marker='o',color='black')
plt.plot(true_smooth_x,true_smooth_y,marker='s',color='purple')
fig.savefig(os.path.join(img_path, figname) + '.png', dpi=300, bbox_inches='tight')
plt.show()
smooth_y = true_smooth_y
smooth_x = true_smooth_x
# Out:
# Processed True Data Stored to true_stress_strain_df
# Processed True Saved to = D:\FAIR_Ontology\results\1018 Steel8\ture_stress_strain_data.csv

# %% [markdown]
# ## Calculate Young's Modulus
#
# - Takes the Young's Modulus from a section of the linear component
# - Appends result to txt file

# %%
"""
Young's Modulus
"""
#Find E
start=10
i=start+1
Ei = np.array([])
Eact = np.array([])
error = 0.1
pings = 0
k=1
while i < len(smooth_x):
    Epoint = (smooth_y[i]-smooth_y[i-1])/(smooth_x[i]-smooth_x[i-1])
    Earr = np.array([Epoint])
    Ei = np.append(Ei,Earr)
    Eavg = np.average(Ei)
    if i >= start+2:
        if Eavg/Ei[k-1] > (3+error) or Eavg/Ei[k-1] < (1-error):
   #       print(Ei[k-1])
            pings = pings+1
        else:
            Eact = np.append(Eact,Ei[k-1])
            pings = 0
            breakpoint = i
    else:
        pass
    
    if pings >= 5:
        Ei = np.delete(Ei,k-1)
        break
    else:
        pass
    i = i + 1
    k = k + 1
  #  print(Eact)

E = np.average(Eact)
print("Young's Modulus = {}".format(int(np.round(E,0)))+' '+ y_units)
txtEdit("Young's Modulus = {}".format(int(np.round(E,0)))+' '+y_units+'\n','a')
  #  print(breakpoint)
# Out:
# Young's Modulus = 87986 MPa

# %% [markdown]
# ## Calculate Proportional Limit
#
# - Calculates proportional limit and adds it to the engineering stress-strain graph
# - Plots and save the figure
# - Appends the result to txt file

# %%
"""
Proportional Limit
"""
#Find Proportional Limit
length = winSize * breakpoint
winMin = length - winSize
winMax = length + winSize
small_x = np.array([])
small_y = np.array([])
sEi = np.array([])
    
winSizeSmall = 1
    
i = winMin
smallError = 0.1
k = 1
while i < winMax:
    pl = i
    sdatx = np.average(strain[i:i+winSizeSmall])
    sdaty = np.average(stress[i:i+winSizeSmall])
    sdatarrX = np.array([sdatx])
    sdatarrY = np.array([sdaty])
    small_x = np.append(small_x,sdatarrX)
    small_y = np.append(small_y,sdatarrY)
    if len(small_x) >= 2:
        sEpoint = (small_y[k-1]-small_y[k-2])/(small_x[k-1]-small_x[k-2])
        sEarr = np.array([sEpoint])
        sEi = np.append(sEi,sEarr)
        if len(sEi) >= 2:
            if sEi[k-3]/sEi[k-2] > (1+smallError) or sEi[k-3]/sEi[k-2] < (1-smallError):
                break
            else:
                pass
        else:
            pass
    else:
        pass
    k = k+1
    i = i+winSizeSmall
    
plx = np.linspace(strain[pl],strain[pl],2)
ply = np.linspace(0,stress[pl],2)

print("Proportional Limit = {:.2f} {}".format(ply[-1], y_units))
txtEdit("Proportional Limit = {:.2f} {}\n".format(ply[-1], y_units), 'a')


# Plot proportional limit
fig, ax = plt.subplots(figsize=(10, 10))
figname = f"{material} Proportional Limit Graph"
plt.title(figname)
plt.ylabel('Stress (' + y_units + ')')
plt.xlabel("Strain")
plt.plot(smooth_x, smooth_y, marker='o', color='black')
plt.plot(plx, ply, marker='o', color='red', linestyle='dashed', label='Proportional Limit')
plt.legend()
plt.text(plx[-1], ply[-1], f'  Proportional Limit: {ply[-1]:.2f} {y_units}', 
         verticalalignment='bottom', horizontalalignment='left')

# Save and display the plot
fig.savefig(os.path.join(img_path, figname)+ '.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Proportional Limit = 161.95 MPa

# %% [markdown]
# ## Calculate the 2% Offset
#
# - Calculates 2% Offset
# - Appends result to txt file

# %%
"""
0.2% Offset
"""
#Find 0.2% Offset
stress_offset = np.copy(smooth_y)
strain_offset = np.copy(smooth_x)
for i in range(len(stress_offset)):
    strain_offset[i] = (stress_offset[i]/E) + 0.002
indx = int(np.argwhere(np.diff(np.sign(strain_offset-smooth_x))).flatten())
  #  print(indx)
mult = 2
length = winSize * indx
  #  print(length)
winMin = length - winSize*mult
winMax = length + winSize*mult
small_strain = np.array([])
small_stress = np.array([])
i = winMin
while i < winMax:
    offset_datx = np.average(strain[i:i+winSizeSmall])
    offset_daty = np.average(stress[i:i+winSizeSmall])
    offset_datarrX = np.array([offset_datx])
    offset_datarrY = np.array([offset_daty])
    small_strain = np.append(small_strain,offset_datarrX)
    small_stress = np.append(small_stress,offset_datarrY)
    i = i+winSizeSmall
    
stress_offset_fine = np.copy(small_stress)
strain_offset_fine = np.copy(small_strain)

for i in range(len(stress_offset_fine)):
    strain_offset_fine[i] = (stress_offset_fine[i]/E) + 0.002
    
window=winMax-winMin

###USE ONLY FOR LARGE DATA SETS
fine_indx = int(np.argwhere(np.diff(np.sign(strain_offset_fine-small_strain))).flatten())
  #  print(fine_indx)
new_indx = winMin+((fine_indx)*winSizeSmall)
  # print(new_indx)
  
print('0.2% Yield Strength = {}'.format(np.round(stress_offset_fine[fine_indx],3)) + y_units)
txtEdit('0.2% Yield Strength = {}'.format(np.round(stress_offset_fine[fine_indx],3))+y_units+'\n','a')
# Out:
# 0.2% Yield Strength = 198.946MPa

# %% [markdown]
# ## Calculate Modulus of Resilience
#
# - Calculates Modulus of Resilience at Proportional Limit
# - Calculates Strain Energy Density at 0.2% Offset
# - Plots the regions under stress-strain graph
# - Appends results to txt file

# %%
"""
Modulus of Resilience
"""
ur = (1/2)*(stress[pl]**2/E)
print('Modulus of Resilience at Proportional Limit = {}'.format(np.round(ur,3))+" "+y_units)
txtEdit('Modulus of Resilience at Proportional Limit = {}'.format(np.round(ur,3))+" "+y_units+'\n','a')
ur_offset = (1/2)*(stress_offset_fine[fine_indx]**2/E)
print('Strain Energy Density at 0.2% Offset = {}'.format(np.round(ur_offset,3))+" "+ y_units)
txtEdit('Strain Energy Density at 0.2% Offset = {}'.format(np.round(ur_offset,3))+" "+y_units+'\n','a')
    
#Plot Moduli of Resilience
ofst2x = np.linspace(strain_offset_fine[fine_indx],strain_offset_fine[fine_indx],2)
ofst2y = np.linspace(0,stress_offset_fine[fine_indx],2)
fig,ax = plt.subplots(figsize=(10,10))
figname = str(material)+' Proportional Limit and 0.2% Yield Strength'
plt.title(figname)
plt.xlim(0,strain[new_indx+winSize])
plt.ylim(0,stress[new_indx+winSize])
plt.ylabel('Stress ('+y_units+')')
plt.xlabel("Strain")
plt.plot(strain_offset,stress_offset,color='b',linestyle='-.')
plt.plot(smooth_x,smooth_y,marker='o',color='black')
plt.plot(plx,ply,marker='^',color='black',linestyle='--')
plt.plot(ofst2x,ofst2y,color='black',linestyle='--')
plt.plot(strain_offset_fine[fine_indx],stress_offset_fine[fine_indx],marker='<',color='b',markersize=10)
plt.annotate('pl=({},{})'.format(np.round(strain[pl],4),np.round(stress[pl],1)),
                (strain[pl],stress[pl]),(strain[pl]+0.0001,stress[pl]))
plt.annotate('0.2%=({},{})'.format(np.round(strain_offset_fine[fine_indx],3),
                                       np.round(stress_offset_fine[fine_indx],1)),
                 (strain_offset_fine[fine_indx],stress_offset_fine[fine_indx]),
                 (strain_offset_fine[fine_indx]+0.0001,stress_offset_fine[fine_indx]-5))
    
plt.fill_between(strain[0:new_indx],stress[0:new_indx],color='darkorange',alpha=0.7,hatch='/',
                     label='u={}'.format(np.round(ur_offset,3)))
plt.fill_between(strain[0:pl],stress[0:pl],color='royalblue',alpha=0.7,hatch='|',
                    label='ur={}'.format(np.round(ur,3)))
plt.legend()
fig.savefig(os.path.join(img_path, figname)+ '.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Modulus of Resilience at Proportional Limit = 0.149 MPa
# Strain Energy Density at 0.2% Offset = 0.225 MPa

# %%
#Plot Moduli of Resilience
ofst2x = np.linspace(strain_offset_fine[fine_indx],strain_offset_fine[fine_indx],2)
ofst2y = np.linspace(0,stress_offset_fine[fine_indx],2)
fig,ax = plt.subplots(figsize=(10,10))
figname = str(material)+' Proportional Limit and 0.2% Yield Strength'
plt.title(figname)
#plt.xlim(0,strain[new_indx+winSize])
#plt.ylim(0,stress[new_indx+winSize])
plt.ylabel('Stress ('+y_units+')')
plt.xlabel("Strain")
plt.plot(strain_offset,stress_offset,color='b',linestyle='-.')
plt.plot(smooth_x,smooth_y,marker='o',color='black')
plt.plot(plx,ply,marker='^',color='black',linestyle='--')
plt.plot(ofst2x,ofst2y,color='black',linestyle='--')
plt.plot(strain_offset_fine[fine_indx],stress_offset_fine[fine_indx],marker='<',color='b',markersize=10)
plt.annotate('pl=({},{})'.format(np.round(strain[pl],4),np.round(stress[pl],1)),
                (strain[pl],stress[pl]),(strain[pl]+0.0001,stress[pl]))
plt.annotate('0.2%=({},{})'.format(np.round(strain_offset_fine[fine_indx],3),
                                       np.round(stress_offset_fine[fine_indx],1)),
                 (strain_offset_fine[fine_indx],stress_offset_fine[fine_indx]),
                 (strain_offset_fine[fine_indx]+0.0001,stress_offset_fine[fine_indx]-5))
    
plt.fill_between(strain[0:new_indx],stress[0:new_indx],color='darkorange',alpha=0.7,hatch='/',
                     label='u={}'.format(np.round(ur_offset,3)))
plt.fill_between(strain[0:pl],stress[0:pl],color='royalblue',alpha=0.7,hatch='|',
                    label='ur={}'.format(np.round(ur,3)))
plt.legend()
fig.savefig(os.path.join(img_path, figname)+ '.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculate Modulus of Toughness
# - Calculates Modulus of Toughness
# - Appends result to txt file

# %%
"""
Modulus of Toughness
"""
#Create Rectangles
area = 0
for i in range(1,len(smooth_x)):
    w = smooth_x[i]-smooth_x[i-1]
    h = (smooth_y[i]+smooth_y[i-1])/2
    rec = w*h
    area=area+rec
print('Modulus of Toughness = {}'.format(np.round(area,3))+" "+y_units)
txtEdit('Modulus of Toughness = {}'.format(np.round(area,3))+" "+y_units+'\n','a')
# Out:
# Modulus of Toughness = 74.416 MPa

# %% [markdown]
# ## Caculate UTS and Strain at Failure
#
# - Caculates UTS
# - Caculates Strain at Failure
# - Caculate elastic recovery
# - Plot UTS and Strain at Failure
# - Saves figure
# - Appends result to txt file

# %%
"""
UTS and Strain at Failure
"""
#Ultimate Tensile Strength
UTS = np.argmax(smooth_y)
#UTS = smooth_y[UTS]
print('UTS={}'.format(np.round(smooth_y[UTS],1))+" "+y_units)
txtEdit('UTS={}'.format(np.round(smooth_y[UTS],1))+" "+y_units+'\n','a')
    
#Strain at Failure
ef = np.argmax(smooth_x)
print('ef={}'.format(np.round(smooth_x[ef],4)))
txtEdit('ef={}'.format(np.round(smooth_x[ef],4))+'\n','a')
xef=np.linspace(smooth_x[ef],smooth_x[ef],2)
yef=np.linspace(0,smooth_y[ef],2)
    
#Find Elastic Recovery
tantheta = stress[pl]/strain[pl]
theta = np.arctan(tantheta)
elastic_ef = smooth_x[ef]-(smooth_y[ef]/np.tan(theta))
print('er={}'.format(np.round(elastic_ef,4)))
txtEdit('er={}'.format(np.round(elastic_ef,4))+'\n','a')
xEAF = np.linspace(elastic_ef,smooth_x[ef],2)
yEAF = np.linspace(0,smooth_y[ef],2)
    
#Plot UTS and Strain at Failure
fig,ax = plt.subplots(figsize=(10,10))
figname = str(material)
plt.title(figname)
plt.ylabel('Stress ('+y_units+')')
plt.xlabel("Strain")
plt.plot(smooth_x,smooth_y,marker='o',color='black')
    
#Proportional Limit
plt.plot(plx,ply,marker='^',color='black',linestyle='--')
plt.annotate('pl=({},{})'.format(np.round(strain[pl],4),np.round(stress[pl],1)),
                 (strain[pl],stress[pl]),(strain[pl]+0.0001,stress[pl]))
    
#0.2% Offset
plt.plot(strain_offset,stress_offset,color='b',linestyle='-.')
plt.annotate('0.2%=({},{})'.format(np.round(strain_offset_fine[fine_indx],3),
                                       np.round(stress_offset_fine[fine_indx],1)),
                 (strain_offset_fine[fine_indx],stress_offset_fine[fine_indx]),
                 (strain_offset_fine[fine_indx]+0.005,stress_offset_fine[fine_indx]))
plt.plot(strain[new_indx],stress[new_indx],marker='<',color='b',markersize=10)
    
#Resilience/Elastic Strain Energy/Toughness
plt.plot(ofst2x,ofst2y,color='black',linestyle='--')
plt.fill_between(smooth_x,smooth_y,color='green',alpha=0.7,hatch='-',
                    label='ut={}'.format(np.round(area,3)))
plt.fill_between(strain[0:new_indx],stress[0:new_indx],color='darkorange',alpha=0.7,hatch='/',
                     label='u={}'.format(np.round(ur_offset,3)))
plt.fill_between(strain[0:pl],stress[0:pl],color='royalblue',alpha=0.7,hatch='|',
                    label='ur={}'.format(np.round(ur,3)))
    
#UTS and Strain at Failure
plt.plot(smooth_x[UTS],smooth_y[UTS],marker='o',markersize=10,color='magenta')
plt.annotate('UTS=({},{})'.format(np.round(smooth_x[UTS],3),np.round(smooth_y[UTS],1)),
                 (smooth_x[UTS],smooth_y[UTS]),(smooth_x[UTS]-0.002,smooth_y[UTS]+5))
plt.plot(xef,yef,color='black',linestyle='--')
plt.plot(smooth_x[ef],smooth_y[ef],marker='o',color='black')
plt.annotate('ef=({},{})'.format(np.round(smooth_x[ef],4),np.round(smooth_y[ef],1)),
                 (smooth_x[ef],smooth_y[ef]),(smooth_x[ef]-0.055,smooth_y[ef]-10))
    
plt.plot(xEAF,yEAF,color='blue',linestyle='-.')
plt.plot(xEAF[0],yEAF[0],marker='o',color='b')
plt.annotate('er=({},{})'.format(np.round(xEAF[0],4),np.round(yEAF[0],1)),
                 (xEAF[0],yEAF[0]),(xEAF[0]-0.055,yEAF[0]-10))
    
    
plt.legend()
fig.savefig(os.path.join(img_path, figname)+ '.png', dpi=300, bbox_inches='tight')
plt.show()
print('\n\n')
# Out:
# UTS=272.7 MPa
# ef=0.3004
# er=0.2998

# %% [markdown]
# # FAIR Graph Making and Data Capture
#
# Here we will be using [PMDco](https://materialdigital.github.io/core-ontology/index-en.html#) Ontology that uses Triplets to build all the data acquired from excel report and the processed results obtained.
#
# In the provided code snippet that creates the RDF file, triplets are constructed based on the Subject, Predicate, and Object. Here's how each component contributes to organizing and structuring the data:
#
# **Subject:** The Subject represents the entity or variable for which information is being described or recorded. In this context, the Subject often corresponds to specific entities in the domain of materials testing, such as materials, test results, or data points. For example, **material_rdf** serves as the Subject when describing test results associated with a particular material.</br>
#
# **Predicate:** The Predicate defines the relationship or property that connects the Subject to the Object in the RDF graph. It signifies how the Subject and Object are related to each other. Predicates often represent attributes, properties, or relationships between entities. For instance, predicates like **test**, **length_rdf**,**width_rdf**, and **yield_strength** specify properties such as the type of test performed, the length of a specimen, its width, and its yield strength, respectively.</br>
#
# **Object:** The Object represents the value or data associated with the Subject-Predicate relationship. It can be a literal value (such as strings, numbers, or dates) or a resource (such as another URI). The Object provides the specific information or data being asserted in the RDF graph. For example, **Literal(s_length)** represents the literal value of the length of a specimen, while **URIRef(PMDco.Material)** denotes the URI reference for the Material class in the PMDco ontology.</br>
#
#
# By structuring the RDF triplets in this way, the code effectively captures and represents information about materials testing in a structured and machine-readable format. Additionally, separating raw data and processed data into distinct URIs (raw_data_uri and processed_data_uri) enhances clarity and organization, facilitating easier interpretation and analysis of the data.</br>
#
#
# **Clarity and Organization:** By saving raw data and processed data under different URIs (raw_data_uri and processed_data_uri), it's easier to distinguish between the two types of data. This separation enhances the clarity of the RDF graph structure and makes it easier for both humans and machines to understand the data model. </br>
#
# **Different Data Processing Stages:** Raw data represents the initial data captured from experiments or measurements, while processed data undergoes some form of analysis or transformation. By storing them separately, it reflects their distinct stages in the data processing pipeline. </br>
#
# **Granularity and Detail:** Raw data typically contains a large volume of data points, whereas processed data may have fewer points but with additional derived information (such as stress-strain curves). Separating them allows for a clear distinction in granularity and detail. </br>
#
# **Flexibility and Modularity:** Storing data under specific URIs provides flexibility for future extensions or modifications to the data model. For example, if you later decide to include additional processing steps or intermediate results, you can easily do so without impacting the existing structure.

# %%
import rdflib

# Create an RDF graph for the experimental data
data_graph = rdflib.Graph()

# Add namespaces
TTO = rdflib.Namespace("https://w3id.org/pmd/tto/")
CORE = rdflib.Namespace("https://w3id.org/pmd/co/")
data_graph.bind("tto", TTO)
data_graph.bind("core", CORE)

# Define the tensile test instance
test_instance = rdflib.URIRef("https://example.org/tensile_test_1")

# Add the tensile test instance to the graph
data_graph.add((test_instance, rdflib.RDF.type, TTO.TensileTest))

# Function to add property with unit as a blank node
def add_property_with_unit(graph, instance, property_uri, value, unit):
    value_node = rdflib.BNode()
    graph.add((instance, property_uri, value_node))
    graph.add((value_node, rdflib.RDF.type, CORE.ValueObject))
    graph.add((value_node, rdflib.RDF.value, rdflib.Literal(value, datatype=rdflib.XSD.float)))
    graph.add((value_node, CORE.unit, rdflib.URIRef(unit)))

# Add properties with units to the tensile test instance
add_property_with_unit(data_graph, test_instance, TTO.OriginalGaugeLength, s_length, "https://w3id.org/pmd/co/unit#mm")
add_property_with_unit(data_graph, test_instance, TTO.OriginalWidth, width, "https://w3id.org/pmd/co/unit#mm")
add_property_with_unit(data_graph, test_instance, TTO.OriginalThickness, thickness, "https://w3id.org/pmd/co/unit#mm")
add_property_with_unit(data_graph, test_instance, TTO.YoungsModulus, float(np.round(E,0)), "https://w3id.org/pmd/co/unit#MPa")
add_property_with_unit(data_graph, test_instance, TTO.YieldStrength, np.round(stress_offset_fine[fine_indx],3), "https://w3id.org/pmd/co/unit#MPa")
add_property_with_unit(data_graph, test_instance, TTO.UltimateTensileStrength, np.round(smooth_y[UTS],1), "https://w3id.org/pmd/co/unit#MPa")
add_property_with_unit(data_graph, test_instance, TTO.PercentageExtension, np.round(smooth_x[ef],4), "https://w3id.org/pmd/co/unit#percent")

# Add PrimaryData, SecondaryData, and MaterialDesignation as strings
data_graph.add((test_instance, CORE.PrimaryData, rdflib.Literal("https://github.com/Wino1301/MaRCN_Tensile_Ontology/tree/main/data/PrimaryData/Steel_1018/Tensile_8.csv", datatype=rdflib.XSD.string)))
data_graph.add((test_instance, CORE.SecondaryData, rdflib.Literal("https://github.com/Wino1301/MaRCN_Tensile_Ontology/tree/main/data/SecondaryData/Steel_1018/Tensile_8.csv", datatype=rdflib.XSD.string)))
data_graph.add((test_instance, CORE.MaterialDesignation, rdflib.Literal("Steel 1018", datatype=rdflib.XSD.string)))

# Serialize the RDF data to a TTL file
ontology_folder = os.path.join(script_dir, 'ontology')
output_file = os.path.join(ontology_folder, "Steel_1018_example.ttl")

data_graph.serialize(destination=output_file, format="turtle")

print(f"Experimental RDF data serialized to {output_file}")
# Out:
# Experimental RDF data serialized to D:\FAIR_Ontology\ontology\Steel_1018_example.ttl

# %%
# Load the RDF graph
g = Graph()
graph_fname = os.path.join(img_path, f"{material.replace(' ', '_')}_graph.rdf")
g.parse(graph_fname, format="xml")

# Define your namespaces
PMDco = Namespace("https://w3id.org/pmd/co/")
RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

# Example: Count the number of triples in the graph
num_triples = len(g)
print("Number of triples in the graph:", num_triples)

# Example: Iterate over triples and extract information
for s, p, o in g:
    # Check if the triple belongs to a specific namespace
    if p.startswith(PMDco):
        print("Subject:", s)
        print("Predicate:", p)
        print("Object:", o)
        print()

# Example: Query the graph using SPARQL
query = """
    SELECT ?subject ?property ?value
    WHERE {
        # ?subject ?property ?value .
    }
"""
try:
    results = g.query(query, initNs={"pmdco": PMDco})
    for i, row in enumerate(results):
        if i % 100 == 0:
            print(row)
except Exception as e:
    print("An error occurred during the query execution:", e)
# Out:
# Number of triples in the graph: 7258
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/8
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.000134659785857704
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/858
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0275198488711516
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1402
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4486.54931640625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/978
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2105.84350585938
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2973
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12627.048828125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/794
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1422.95727539063
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1339
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4051.63427734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1139
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2866.8798828125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2698
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.23893705083378
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1893
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.324590360677093
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2090
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.07812750123091
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1263
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3569.2119140625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3327
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12589.7158203125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2666
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.01314441187628
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1147
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2905.263671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2293
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 2.38154625965603
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/209
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 179.234527587891
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2808
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.01482188774593
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/92
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.14118310929804007
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1509
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0901030469580922
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.000306056520884678
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/7
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.00011448616293763498
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2480
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12144.61328125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1735
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 7242.5302734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2544
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12242.630859375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3041
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 7.65894709600456
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3194
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.7383574105645
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1865
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10077.8828125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1730
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.125287737163007
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2649
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.89312114639528
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/51
# Predicate: https://w3id.org/pmd/co/hasTrueStrain
# Object: 0.008889985556828031
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2805
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12521.0908203125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1685
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.11721488029113
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3378
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12442.423828125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2864
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.41005283667095
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/420
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 437.550354003906
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2926
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.84757328106411
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/503
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 591.666931152344
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1923
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10662.3681640625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2923
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.82638103587874
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1368
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4253.44287109375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1883
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.297739079386219
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2352
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 2.797595993414
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2629
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12354.3662109375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1157
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0498164734640062
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/344
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 317.734039306641
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1033
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0395154491602347
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1779
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 8145.3662109375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3124
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.24457390679367
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/887
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0293359479005352
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1530
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0930770655290593
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1856
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.236515475834012
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2012
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.7606999386812
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2220
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11628.7451171875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/776
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1363.09777832031
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2669
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.03424259348162
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2415
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12036.15625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1943
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.489376044996306
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/873
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1712.53942871094
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1031
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2335.947265625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2531
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.06064961551078
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/450
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 490.771392822266
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1271
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3610.96948242188
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1175
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3057.8251953125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2399
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.12920643462189
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/807
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0245918907498611
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3114
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12673.7626953125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1874
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10201.7763671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1316
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3905.93530273438
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1829
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 9413.578125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2833
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12545.3935546875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/112
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.000854128885266047
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2622
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.70263215227373
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/550
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0114975217261139
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/832
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1560.38354492188
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2288
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11787.255859375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2696
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.22473158760317
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/125
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00132565135433594
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1265
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0603095066512373
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2484
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.72894604204543
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2751
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.61269728912361
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1229
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3364.04638671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1475
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 5023.32470703125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2226
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.9086751386369
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1846
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.218292694470137
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1855
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.234594477504715
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3143
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.37847574128159
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/889
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0294683794240603
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2842
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12553.0322265625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1251
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0589469853625536
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2588
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12302.0693359375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3138
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.34317302776821
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3135
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.32207484616287
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1991
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.676185674663856
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/407
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 414.919769287109
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1532
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 5463.41748046875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1352
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4143.734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/473
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 522.2890625
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/1
# Predicate: https://w3id.org/pmd/co/hasStress
# Object: 0.6150378893904052
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3166
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.54088163448818
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2010
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.752578049130961
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1092
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2626.55200195313
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/132
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 87.5723876953125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2411
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.21397169007309
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2541
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12237.931640625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/682
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.01745654647354
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1265
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3578.07275390625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1693
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.118748332014065
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2946
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.98855409844168
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3017
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 7.48955628348835
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2621
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12342.6318359375
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/37
# Predicate: https://w3id.org/pmd/co/hasTrueStress
# Object: 129.24087292282726
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/20
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.79650108824092e-05
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/322
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 286.502777099609
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/77
# Predicate: https://w3id.org/pmd/co/hasStress
# Object: 291.20303775767763
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2000
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.712337870780602
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1656
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.112324912905451
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1894
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.327318495536446
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2545
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.15943406967767
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/351
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00549531644398428
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2494
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12165.484375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1895
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10437.1708984375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2169
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.50650537086971
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/487
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00897734828728914
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2322
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 2.58596132023581
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3155
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12679.7060546875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2533
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12229.5625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/23
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.000141083497198334
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1584
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 5893.220703125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1985
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10958.7802734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2250
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 2.07802031634696
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1366
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4238.150390625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3040
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12650.98046875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3393
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12356.0947265625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3182
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.65377748830564
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1631
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.108313837543819
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1894
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10426.767578125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/285
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 248.000259399414
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2556
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.23693361206301
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1050
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0405903336545356
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3071
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 7.87053427173145
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/422
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00730875702035462
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2555
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12264.125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2831
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12544.2861328125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3370
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12475.935546875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2573
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.35695594622143
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2746
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.57753334267386
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2250
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11702.27734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2125
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.21949505030759
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/954
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0333464812033247
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/205
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 178.131042480469
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/21
# Predicate: https://w3id.org/pmd/co/hasStress
# Object: 46.23473453682585
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1851
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.22724609500844
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2757
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.65508084817179
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2856
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.35355694664963
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/873
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0284878586430472
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/401
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 403.148010253906
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2779
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12506.48046875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/745
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0209195676038411
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1238
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3415.34912109375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2849
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12556.185546875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2638
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12364.2529296875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/458
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 509.58544921875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1069
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0420981558167745
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1992
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.680198219768926
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1396
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4439.93017578125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2100
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.11894352797069
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1538
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0939804411504787
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2138
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11419.599609375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/419
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00690380223065346
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1321
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3934.232421875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1699
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.119761465456094
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/78
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.09179541701047574
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2784
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.84556984229334
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/35
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11.3244647979736
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1916
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10614.22265625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3281
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 9.3522088832999
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1706
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 6966.22265625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/798
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1445.21569824219
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2728
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12458.568359375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1747
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 7353.35888671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/575
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0127394894920775
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1197
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0533877935854156
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3246
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 9.1051774330283
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1006
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2227.76098632813
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2761
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.6833967797304
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/233
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00325696358092443
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2932
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.88990934266098
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2624
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.71669698579557
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1593
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 5969.39453125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/895
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1790.23205566406
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2613
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12332.0693359375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2290
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 2.3603083796645
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/563
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0120724269695251
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/911
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0305563588230774
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/797
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0237419461231815
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2713
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12444.396484375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3259
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 9.19707010014303
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3268
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 9.26059654428013
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/387
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 387.109222412109
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2625
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.72373033387907
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2766
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12490.8876953125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1666
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.11429195349453
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1288
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0629388631100204
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/445
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00805065595020039
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/43
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.002490811643446603
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/2
# Predicate: https://w3id.org/pmd/co/hasTrueStress
# Object: 1.6934102308677272
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2388
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.05156672818907
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/488
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00897126285823958
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/82
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 25.5803356170654
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/822
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0253742799290825
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1213
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3274.14013671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1615
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 6155.87451171875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3227
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 8.97122903241165
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2233
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 1.95818424670346
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2610
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.61791253162869
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2494
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.79959943218477
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2209
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11601.337890625
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/31
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.0013344112024873422
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3027
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12647.0341796875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1445
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0814968332892653
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/27
# Predicate: https://w3id.org/pmd/co/hasStress
# Object: 72.15557942412224
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1367
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4246.923828125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1564
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0982943418680128
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3203
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12685.7294921875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3015
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12647.552734375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1207
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3235.29809570313
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/518
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 623.265014648438
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/559
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 715.523742675781
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2627
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 4.73793579710968
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/729
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1203.89245605469
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2737
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 5.51405253334292
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1803
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 8790.1796875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/220
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00340543677199946
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1083
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 2584.14868164063
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1213
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0551373085076824
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/96
# Predicate: https://w3id.org/pmd/co/hasTrueStrain
# Object: 0.14435522792301247
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1206
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3230.86303710938
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2455
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12105.7587890625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2865
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.41708525343187
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1721
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 7105.95458984375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1904
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 10520.0078125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3089
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12664.900390625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3026
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 7.55303616149672
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3305
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12624.7744140625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3215
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12677.8818359375
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/80
# Predicate: https://w3id.org/pmd/co/hasTrueStress
# Object: 322.3540686741335
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/710
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1141.86608886719
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1821
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.182571715257354
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/946
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0329875436623018
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/864
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1676.88293457031
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3310
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 9.55690334065206
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2517
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 3.96177156342514
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2243
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11684.0751953125
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2850
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.3111752502466
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/71
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 18.6894454956055
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/54
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 16.6680660247803
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/465
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00835564408450352
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1706
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.120756940148994
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2951
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 7.02390430940636
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2477
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12140.9638671875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1296
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 3773.66259765625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/503
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00995625835318549
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1680
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.116133723921366
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/413
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00673446886909857
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/46
# Predicate: https://w3id.org/pmd/co/hasTrueStrain
# Object: 0.003338034635882635
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1470
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 4983.44921875
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2596
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12314.15234375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/78
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 24.6360378265381
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2315
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11841.478515625
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1996
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.69608873657532
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3360
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12506.21484375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1868
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.261527016690224
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/85
# Predicate: https://w3id.org/pmd/co/hasStrain
# Object: 0.11648883418707999
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1053
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.0408290178060901
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2947
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 6.99572621358879
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2351
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 11916.994140625
#
# Subject: https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/105
# Predicate: https://w3id.org/pmd/co/hasStress
# Object: 299.69989584961957
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2827
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 12540.34375
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/284
# Predicate: https://w3id.org/pmd/co/hasDisplacement
# Object: 0.00407075351947185
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/789
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 1406.51721191406
#
# Subject: https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1694
# Predicate: https://w3id.org/pmd/co/hasLoad
# Object: 6856.47021484375
#
# ...
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/805'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0245944937236976', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1966'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('10887.2080078125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2953'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12620.3818359375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3178'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12680.609375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2220'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('1.86638610883005', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1021'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('2295.91259765625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1398'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('4458.8447265625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2139'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('1.29487069769152', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/917'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('1865.32958984375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1463'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0840737737493958', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3277'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12651.4794921875', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/332'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.00511359833441872', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2078'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('11253.6435546875', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1885'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.303006756283566', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/33'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('10.8487224578857', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1259'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0597358847048503', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2394'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('3.09394935591467', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1593'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.102448506212085', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/614'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0142157276318079', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1414'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('4573.1220703125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2739'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12469.021484375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1092'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0441390437376589', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/317'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('275.150299072266', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3226'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('8.96424318177946', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/145'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.00200860957053862', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2523'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12211.8955078125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/secondary_data//StressStrainDataPoint/16'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasStress'), rdflib.term.Literal('29.792254983250395', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3062'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('7.80700782759436', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/834'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('1569.92468261719', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1314'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('3885.23291015625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/97'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasTrueStrain'), rdflib.term.Literal('0.14740427706688025', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2253'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('11710.7255859375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1812'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('9017.3330078125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2532'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12226.5107421875', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1711'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.121938744840435', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1901'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('10494.6103515625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2432'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('3.36212555392035', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2128'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('11395.818359375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/248'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.00325727417336509', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1970'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('10900.064453125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/43'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.000419420246402634', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2787'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12509.943359375', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/secondary_data//TrueStressTrueStrainDataPoint/9'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasTrueStress'), rdflib.term.Literal('11.462368912797418', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2652'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('12378.6796875', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1038'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0397684087406282', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/3385'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('10.0860826901937', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1596'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.103353213333748', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/2295'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('11800.1494140625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/273'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('233.161682128906', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1446'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasDisplacement'), rdflib.term.Literal('0.0817219950735938', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/506'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('598.696105957031', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1052'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('2433.39501953125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1535'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('5490.2978515625', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/299'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('254.885131835938', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/138'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('95.1912307739258', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))
# (rdflib.term.URIRef('https://materialtest.org/6061_Aluminum2/test_n/primary_data//LoadDisplacementPoint/1736'), rdflib.term.URIRef('https://w3id.org/pmd/co/hasLoad'), rdflib.term.Literal('7249.67578125', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')))

# %% [markdown]
# Note: This are some methods to extract data from RDF files, and with such we ensure all dictionaries are equal, now we can compare multiple test using this methods.

# %%
# Read and display the contents of the generated TTL file
with open(output_file, 'r') as file:
    ttl_content = file.read()

print(ttl_content)
# Out:
# @prefix core: <https://w3id.org/pmd/co/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix tto: <https://w3id.org/pmd/tto/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://example.org/tensile_test_1> a tto:TensileTest ;
#     core:MaterialDesignation "Steel 1018"^^xsd:string ;
#     core:PrimaryData "https://github.com/Wino1301/MaRCN_Tensile_Ontology/tree/main/data/PrimaryData/Steel_1018/Tensile_8.csv"^^xsd:string ;
#     core:SecondaryData "https://github.com/Wino1301/MaRCN_Tensile_Ontology/tree/main/data/SecondaryData/Steel_1018/Tensile_8.csv"^^xsd:string ;
#     tto:OriginalGaugeLength [ a core:ValueObject ;
#             rdf:value "50"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#mm> ] ;
#     tto:OriginalThickness [ a core:ValueObject ;
#             rdf:value "3.18"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#mm> ] ;
#     tto:OriginalWidth [ a core:ValueObject ;
#             rdf:value "13.46"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#mm> ] ;
#     tto:PercentageExtension [ a core:ValueObject ;
#             rdf:value "0.3004"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#percent> ] ;
#     tto:UltimateTensileStrength [ a core:ValueObject ;
#             rdf:value "272.7"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#MPa> ] ;
#     tto:YieldStrength [ a core:ValueObject ;
#             rdf:value "198.946"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#MPa> ] ;
#     tto:YoungsModulus [ a core:ValueObject ;
#             rdf:value "87986.0"^^xsd:float ;
#             core:unit <https://w3id.org/pmd/co/unit#MPa> ] .
